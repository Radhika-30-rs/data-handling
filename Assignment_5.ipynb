# %% [markdown]
# ques 1**What is the difference between interpreted and compiled languages0?**
#
# Answer-The key difference between compiled and interpreted languages lies in how they are processed: compiled languages are translated into machine code before execution, while interpreted languages are translated and executed line by line during runtime.

# %% [markdown]
# ques2-**What is exception handling in Python?**
#
# Answer - Exception handling in python is a mechanism that allows you to gracefully handle runtime errors (called exceptions) so that your program doesn't crash unexpectedly.

# %% [markdown]
# ques 3-**What is the purpose of the finally block in exception handling?**
#
# Answer-purpose - **To clean up resources(eg;closing files,releasing netork connections,or freeing memory)**
#
# to ensure important final steps are executed regardless of whether an error occured.

# %% [markdown]
# ques 4-**what is logging in python?**
#
# Answer-**Logging** in python is the process of tracking events that happen when your program runs.It's like writing a diary of your program's activity ,which is super useful for debugging,monitoring and auditing.

# %% [markdown]
# ques5 -**What is the significance of the _ _del_ _ method in Python?**
#
# Answer-
#
# *   Used to clean up resources like closing files.releasing memory or disconnecting from a network
# *   Called **automatically** by python's garbage collector.

# %% [markdown]
# ques6-**What is the difference between import and from ... import in Python?**
#
# Answer- **Import statemnt-**
#
# imports the entire module.
#
# Access function using module name(eg:math sqrt()
#
# Avoids naming conflicts by keeping everything under the module's namespace
#
# **from . . . import**
#
# Imports specific functions,classes,or variables
#
# No need to use the module name prefix
#
# Cleaner and shorter if you're only using a few things from the module.

# %% [markdown]
# ques 7-**How can you handle multiple exceptions in Python?**
#
# Answer-try Block: Encloses the code that might raise exceptions.
#
# except Blocks: Each except block catches a specific type of exception.
#
# Multiple except Blocks: You can have multiple except blocks to handle different exceptions.
#
# Exception Handling: When an exception occurs within the try block, Python checks each except block sequentially, and the first matching except block is executed.

# %% [markdown]
# ques8-**What is the purpose of the with statement when handling files in Python?**
#
# Answer- The with statement is used to open files safely and automatically manage resources . It ensures that the file is properly closed after its suite finishes- even if an exception occurs.

# %% [markdown]
# ques9-**What is the difference between multithreading and multiprocessing?**
#
# Answer-**Multithreading :**
# * Uses multiple threads within a single process.
# * Threads share the same memory space .
# *  Best for **I/O** -bound tasks (like reading files, web requests )
#
# **Multiprocessing**
# * Each process has its own memory space
# *   Uses multiple processes
# *  Best for **Cpu - bound tasks** (like data processing, number crunching)

# %% [markdown]
# ques 10-**What are the advantages of using logging in a program?**
#
# Answer-Logging in programming offers numerous advantages, including aiding in debugging, monitoring application health, improving security, and facilitating performance analysis and optimization, making it a crucial tool for software development.

# %% [markdown]
# ques11-**What is memory management in Python?**
#
# Answer-Memory management in python is the process by which python allocates , manages and releases memory automatically so you don't have to do it manually like in some other languages .

# %% [markdown]
# ques 12-**What are the basic steps involved in exception handling in Python?**
#
# Answer- 1. Use try block (wraps the code that might cause an error).
# 2. use except Block(s) -Catch and handlespecific exceptions.
# 3. Optional :Use else block -Runs if no exception was raised in the try block .
# 4.  Optional :Use finally block -Always runs ,whether an exception occured or not.Great for cleanup tasks.

# %% [markdown]
# ques13-**Why is memory management important in Python?**
#
# Answer-Becuse it prevents memory Leaks .
#
# it Optimizes Performance
#
# It enables Scalabiltiy
#
# It reduces developer Burden

# %% [markdown]
# ques14-**What is the role of try and except in exception handling?**
#
# Answer-Role of  try and except in exception handling:
# In exception handling, try and except blocks work together to gracefully manage potential errors or exceptions during code execution, preventing program crashes and allowing for controlled error handling

# %% [markdown]
# ques 15-**How does Python's garbage collection system work?**
#
# Answer- Python's garbage collection system automatically manages memory by reclaiming memory occupied by objects that are no longer referenced, primarily using reference counting and a cyclic garbage collector to handle circular references.
#
# Reference Counting:
# Python keeps track of how many variables are pointing to each object (its reference count). When an object's reference count reaches zero, meaning no variables are pointing to it, the object is considered garbage and the memory it occupies is freed.
#
# Cyclic Garbage Collection:
# Reference counting alone can't handle circular references (where two or more objects reference each other, preventing their garbage collection). Python's cyclic garbage collector identifies and breaks these cycles, ensuring that memory is freed even in such cases.
#
# Automatic and Periodic:
# The garbage collector runs automatically and periodically, rather than requiring manual intervention from the programmer.
#
# Generations:
# The garbage collector uses a generational approach, dividing objects into generations based on their age (younger objects are collected more frequently). This optimizes performance by focusing on the objects that are most likely to be garbage.
#
# Stop-the-world:
# Python's garbage collection is "stop-the-world", meaning the program must pause while the garbage collector is running.

# %% [markdown]
# ques 16-**What is the purpose of the else block in exception handling?**
#
# Answer- The primary purpose of the 'else' block is to define a section of code that should run only if the code in the 'try' block does not raise an exception.This allows you to separate the code that might cause an exception from the code that should run if no exceptions occur.

# %% [markdown]
# ques 17-**What are the common logging levels in Python?**
#
# Answer-The common logging levels in python  in order of increasing severity are:
# 1.  DEBUG =10
# 2.  INFO= 20
# 3.  WARNING = 30
# 4.  ERROR = 40
# 5. CRITICAL = 50

# %% [markdown]
# ques 18-**What is the difference between os.fork() and multiprocessing in Python?**
#
# Answer- os.fork()-
# os.fork() is a low -level function that creates a new process by duplicating the calling process. the new process is called the child process ,and the original process is the parent process.
#
# **Platform-** 'os.fork()' is available only on Unix -like operating sustem (Linux,macos etc ).It does not work on windows.
#
# **Process creation**- when 'os.fork()' is called ,the operating system creates a new process that is a copy of the current process. Both processes will continue executing from the poiny where 'fork()' was created.
#
# 'mltiprocessing'
#
# **definition**- The 'multiprocessing' module is a high level module in python that provides a way to create and manage multiple processes. It abstracts away many of the complexities involved in process management.
#
# **Platform**- The' multiproceesing' module is cross-Platform and works on both Unix -like systems and windows.
#
# **Process creation**- The'multiprocessing' module provides a 'Process' class that allows you to create new processes  easily.You can specify the target function to run in the new process.

# %% [markdown]
# ques 19-**What is the importance of closing a file in Python?**
#
# Answer- Closing files in Python is an essential practice that helps maintain data integrity, prevent resource leaks, and ensure the reliability of your applications. By mastering file handling techniques, you can write more robust and efficient Python code that effectively manages file resources.

# %% [markdown]
# ques 20-**What is the difference between file.read() and file.readline() in Python?**
#
# Answer-Both are used to read data from a line, but they serve different purposes.
#
# '**file.read()-**' purpose - The  'read()' method reads the entire content of the file and returns it as a single string.
#
# **Usage**- If called without arguments ,it reads the entire file. if called with an integer argument ,it reads up to that many bytes from the file.
#
# **Return value**-Returns a string containg the contents of the file (or the specified number of bytes).
#
# 'file.readline()' **purpose**- the readline() method reads a single line and returns it as a string .It reads it as a string. It reads upto end including the newline character('\n').
#
# **usage**- Typically used in a loop to read a file line by line.
#
# **Return value**- Returns a string containg the next line from the file, including the newline character at the end.If the end of the file is reached,It returns an empty strings.

# %% [markdown]
# ques 21-**What is the logging module in Python used for?**
#
# Answer- The Python logging module is used to track events, debug issues, and monitor the health of Python applications by capturing and storing information about program execution. It's a powerful tool for developers to understand application behavior and troubleshoot problems.

# %% [markdown]
# ques 22-**What is the os module in Python used for in file handling?**
#
# Answer-Python has a built-in os module with methods for interacting with the operating system, like creating files and directories, management of files and directories, input, output, environment variables, process management, etc.

# %% [markdown]
# ques 23-**What are the challenges associated with memory management in Python?**
#
# Answer-Memory managemnt in python largely handeled automatically by the interpreter,still presents several challenges and considerations for developers.
#
# 1. Garbage collection
#
# 2. Fragmentation
#
# 3. Memory leaks
#
# 4. Object Lifetimes
#
# 5. Memory  Overhead

# %% [markdown]
# ques 24-**How do you raise an exception manually in Python?**
#
# Answer-We can raise an exception manually in python  using the'raise' statement . This allows you to  create  and throw  exceptions in your code, which can be useful for an error handling and control flow.

# %% [markdown]
# ques25-**Why is it important to use multithreading in certain applications?**
#
# Answer-Multithreading is aprogramming technique that allows multiple threads to run concurrently within  a single process.It is particularly important in certain applications for several reasons:
#
# 1. Improved Perfprmance and responsivess
#
# 2. Efficient Resource Utilization
#
# 3. Simplified Program structure
#
# 4. Real-time processing
#
# 5. Scalability
#
# 6. Bckground Processing

# %% [markdown]
# **Practical questions:**

# %% [markdown]
# ques1 **How can you open a file for writing in Python and write a string to it?**

# %%
with open('example.txt','w') as file:
  file.write("Hello,world!")

# %% [markdown]
# ques2 **Write a Python program to read the contents of a file and print each line**

# %%
with open('example.txt','r') as file:
  for line in file:
    print(line.strip())
# Out:
# Hello,world!

# %% [markdown]
# ques3-**How would you handle a case where the file doesn't exist while trying to open it for reading**

# %%
from os import name

filename ='example.txt'
try:
  with open('example.txt','r') as file:
   for line in file:
    print(line.strip())
except FileNotFoundError:
 print(f"Error:The file '{filename}'' does not exist.")
# Out:
# Hello,world!

# %% [markdown]
# ques4-**Write a Python script that reads from one file and writes its content to another file**

# %%
source_file ='source.txt'
destination_file ='destination.txt'

try:
  with open(source_file,'r') as src:
    with open(destination_file,'w') as dest:
      for line in src:
        dest.write(line)
    print(f"Contents copied from'{source_file} to '{destination_file}'.")
except FileNotFoundError:
  print(f"Error: The file '{source_file}' does not exist.")
# Out:
# Error: The file 'source.txt' does not exist.

# %% [markdown]
# ques 5-**How would you catch and handle division by zero error in Python?**

# %%
try:
  numerator = 10
  denominator = 0
  result = numerator / denominator
except: ZeroDivisionError
print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %% [markdown]
# ques6-**Write a Python program that logs an error message to a log file when a division by zero exception occurs**

# %%
import logging
logging.basicConfig(filename='error.log' ,
                    level=logging.ERROR,
                    format='%(asctime)s -%(levellname)s - %(message)s')
try:
  x= 10
  y = 0
  result = x/y
except ZeroDivisionError as e:
  logging.error("Division by zero occured: %s" ,e)
  print("An error occured.Check the log file for details.")
# Out:
# ERROR:root:Division by zero occured: division by zero
# An error occured.Check the log file for details.

# %% [markdown]
# ques7 -**How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?**

# %%
import logging
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logging.debug("This is  a DEBUG message - useful for diagnosing problem.")
logging.info("This is an INFO message - general information.")
logging.warning("This is a WARNING message- something unexpected happened.")
# Out:
# WARNING:root:This is a WARNING message- something unexpected happened.

# %% [markdown]
# ques 8-**Write a program to handle a file opening error using exception handling**

# %%
def open_file(filename):
  try:
    with open(filename, 'r') as file:
      content = file.read()
      print("File content:\n" , content)
  except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
  except IOError:
    print(f"Error: Could not read the file'{filename}',")
filename = input("Enter the filename to open: ")
open_file(filename)

# %% [markdown]
# ques9-**How can you read a file line by line and store its content in a list in Python**

# %%
def read_file_lines(filename):
  try:
    with open(filename, 'r') as file:
      lines = file.readlines()
      return [line.strip() for line in lines]
  except FileNotFoundError:
    print(f"Error:The file '{filename}'was not found.")
    return []
  except IOError:
    print(f"Error:Could not read the file'{filename}'.")
    return[]
filename = input("Enter the filename: ")
lines_list = read_file_lines(filename)
print("Lines in the file:",lines_list)

# %% [markdown]
# ques 10-**How can you append data to an existing file in Python?**

# %%
def append_to_file(filename,data):
  try:
    with open(filename,'a') as file:
      file.write(data + '\n')
    print("Data appended successfully.")
  except IOError:
    print(f"Error: Could not write to the file '{filename}'.")
filename = input("Enter the filename to append to: ")
data = input("Enter the data to append: ")
append_to_file(filename,data)

# %% [markdown]
# ques11-**Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist**

# %%
def get_dict_value(my_dict,key):
  try:
    value = my_dict[key]
    print(f"Value for '{key}':{value}")
  except KeyError:
    print(f"Error: Key'{kry}' not found in the dictionary.")
sameopenfile = {
    'name': 'Alice',
    'age': 39,
    'city':'New York'
}

key_to_lookup = input("Enter the key you want to access:")
get_dict_value(sample_dict,key_to_lookup)

# %% [markdown]
# ques12**Write a program that demonstrates using multiple except blocks to handle different types of exceptions**

# %%
def divide_numbers():
  try:
    num1 = int(input("Enter a numerator: "))
    num2 = int(input("Enter a denominator: "))
    result = num1/num2
    print (f"Result:{result}")
  except ValueError:
    print("Error : Invalid input. Please enter integers only.")
  except ValueError:
    print("Error:   Invalid input.Please enter integers only.")
  except ZeroDivisorsError:
   print("Error: Cannot divide by zero.")
  except Exception as e:
   print(f"An unexpected error  occured:{e}")

divide_numbers()
# Out:
# Enter a numerator: 12
# Enter a denominator: 2
# Result:6.0

# %% [markdown]
# ques 13-**How would you check if a file exists before attempting to read it in Python**

# %%
import os
file_path ='example.txt'

if os.path.exists(file_path):
  with open (file_path,'r') as file:
    content = file.read()

  else:
    print("file does not exist")

# %% [markdown]
# ques 14-**Write a program that uses the logging module to log both informational and error messages**

# %%
import logging
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def divide(a,b):
  try:
    logging.info(f"trying to divide {a} by {b}")
    result = a/b
    logging.info(f"Result: {result}")
    return result
  except ZeroDivisorError as e:
    logging.error("Attempted to divide by zero.")
    logging.exception(e)
divide(10,2)
divide(5,0)

# %% [markdown]
# ques15-**Write a Python program that prints the content of a file and handles the case when the file is empty**

# %%
def print_file_content(file_path):
  try:
    with open(dile_path,'r') as file:
      content = file.read()
      if content:
        print("file Content:")
        print(content)
      else:
        print("The file is empty.")
  except FileFoundError:
    print(f"File '{file_path}' not found.")
  except Exception as e:
    print(f"An error occured: {e}")

file_name = 'example.txt'
print_file_content(file_name)

# %% [markdown]
# ques 16-**Demonstrate how to use memory profiling to check the memory usage of a small program**

# %%
from  memory_profiler import profile
def create_large_file():
  large_list =[x * 2 for x in  range(100000)]
  return sum(large_list)
if__name__ == "__main__":
  create_large_list()

# %% [markdown]
# ques 17-**Write a Python program to create and write a list of numbers to a file, one number per line.**

# %%
def write_numbers_to_file(file_path,numbers):
  try:
    with open (file_path, 'w') as file:
      file.write(f"{number}\n")
    print(f"Successfully wrote
          {len(numbers)} numbers to {file_path}")
 except Exception as e:
           print(f"An error occured: {e}")
number_list = list(range(1,11))
write_numbers_to_file("numbers.txt",number_list)

# %% [markdown]
# ques 18-**How would you implement a basic logging setup that logs to a file with rotation after 1MB?**

# %%
import logging
from logging.handlers import RotatingFileHandler

log_handler = RotationFileHandler(
    'app.log' , maxBytes=1_000_000,
backupcount=3
)
logging.basicConfig(
    handler=[log_handler],
    level=logging.Info,
)
formatter = logging.Formatter('%(asctime)s - &(levelname)s - %(message)s' )
log_handler.setFormatter(formatter)
logger.addHandler(log_handler)
logger.info("App staarted.")
logger.warning("This is a warning.")
logger.error("Something went wrong.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-405f6ce15f1a> in <cell line: 0>()
#       2 from logging.handlers import RotatingFileHandler
#       3
# ----> 4 log_handler = RotationFileHandler(
#       5     'app.log' , maxBytes=1_000_000,
#       6 backupcount=3
#
# NameError: name 'RotationFileHandler' is not defined

# %% [markdown]
# ques 19-**Write a program that handles both IndexError and KeyError using a try-except block**

# %%
def handle_errors():
  my_list = [10,20,30]
  my_dict = {'a':1,'b':2}
  try:
    print("list item:", my_list[5])
    print("Dict value:",my_dict['z'])
  except IndexError Caught as ie:
      print("IndexError Caught:", ie)
  except KeyError as ke:
      print("KeyError caught:",ke)
handle_errors()
# Out:
#   File "<ipython-input-3-143896c326a0>", line 7
#     except IndexError Caught as ie:
#                       ^
# SyntaxError: invalid syntax

# %%
ques20-**How would you open a file and read its contents using a context manager in Python?**

# %%
with open('filename.txt', 'r') as file:
  contents = file.read()
  print(contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-59ac9282c7bb> in <cell line: 0>()
# ----> 1 with open('filename.txt', 'r') as file:
#       2   contents = file.read()
#       3   print(contents)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'filename.txt'

# %% [markdown]
# ques21-**Write a Python program that reads a file and prints the number of occurrences of a specific word**

# %%
def count_word_in_file(filename,word_to_count):
  try:
    with open(filename,'r',encoding='utf-8') as file:
      contents = file.read()
      word_count = contents.lower().count(word_to_count.lower())
      print(f"The word '{word_to_count}' appears {word_count} times in '{filename}'.")
  except FileNotFoundError:
      print(f"The file'{filename}' was not found.")
  except Exception as e:
      print(f"An error occured : {e}")
  filename = 'example.txt'
  word = 'Python'
  count_word_in_file(filename,word)

# %% [markdown]
# ques 22-**How can you check if a file is empty before attempting to read its contents**

# %%
import os
file_path = "example.txt"

if os.path.getsize(file_path) > 0:
  with open(file_path, 'r') as file:
    content = file.read()
    print(content)
else:
  print("The file is empty.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-72fa4cb5063f> in <cell line: 0>()
#       2 file_path = "example.txt"
#       3
# ----> 4 if os.path.getsize(file_path) > 0:
#       5   with open(file_path, 'r') as file:
#       6     content = file.read()
#
# /usr/lib/python3.11/genericpath.py in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %% [markdown]
# ques 23-**Write a Python program that writes to a log file when an error occurs during file handling.**

# %%
import logging
logging.basicConfig(filename='error.log',level=logging.Error,
                    format='%(asctime)s - %(levelname)s - %(message)s')
def read_file(file_path):
  try:
    with open(file_path,'r') as file:
      content = file.read()
      print("File content:\n", content )
  except Exception as e:
    logging.error(f"Error reading file{file_path}: {e}")
    print("An error occured. check error.log for details.")

file_to_read = 'example.txt'
read_file(file_to_read)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-b7ca16022a97> in <cell line: 0>()
#       1 import logging
# ----> 2 logging.basicConfig(filename='error.log',level=logging.Error,
#       3                     format='%(asctime)s - %(levelname)s - %(message)s')
#       4 def read_file(file_path):
#       5   try:
#
# AttributeError: module 'logging' has no attribute 'Error'
